# %%
import os
os.getcwd()
os.chdir('/home/jovyan/signal-extraction/simulator_code')

# %%
# !pip install papermill
import papermill as pm
# Out:
# Requirement already satisfied: papermill in /srv/conda/envs/notebook/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: click in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (8.3.0)
# Requirement already satisfied: pyyaml in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (6.0.3)
# Requirement already satisfied: nbformat>=5.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (5.10.4)
# Requirement already satisfied: nbclient>=0.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (0.10.2)
# Requirement already satisfied: tqdm>=4.32.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (4.67.1)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (2.32.5)
# Requirement already satisfied: entrypoints in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (0.4)
# Requirement already satisfied: tenacity>=5.0.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (9.1.2)
# Requirement already satisfied: ansicolors in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (1.1.8)
# Requirement already satisfied: aiohttp>=3.9.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from papermill) (3.13.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp>=3.9.0->papermill) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp>=3.9.0->papermill) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp>=3.9.0->papermill) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp>=3.9.0->papermill) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp>=3.9.0->papermill) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp>=3.9.0->papermill) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiohttp>=3.9.0->papermill) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.9.0->papermill) (3.11)
# Requirement already satisfied: typing-extensions>=4.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp>=3.9.0->papermill) (4.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from nbclient>=0.2.0->papermill) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from nbclient>=0.2.0->papermill) (5.9.1)
# Requirement already satisfied: traitlets>=5.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from nbclient>=0.2.0->papermill) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (2.9.0)
# Requirement already satisfied: pyzmq>=23.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbclient>=0.2.0->papermill) (4.5.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from nbformat>=5.2.0->papermill) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from nbformat>=5.2.0->papermill) (4.25.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->papermill) (0.28.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.2.0->papermill) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->papermill) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->papermill) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->papermill) (2025.10.5)

# %%
start_date = ["1940-01-01", "1940-01-01", "1940-01-01", "1980-01-01", "1940-01-01", "1940-01-01","1940-01-01",]
end_date = ["2024-12-31", "2007-12-31", "1974-12-31", "2014-12-31", "1969-12-31", "1989-12-31", "2009-12-31",]
data_sources = ['ar_cfs']*7
vae_signal = ['~/signal-extraction/vae_input_data/AR_cfs.csv']*7
sigvar = ['cfs']*7
run_num = ['0','0','1','2','1','2','3']
types = ['All'] + ['Standard'] + ['Block']*2 + ['KFold']*3
steps = [20, 17, 10, 10, 15, 15, 15]

if len(start_date) == len(end_date) == len(data_sources) == len(run_num) == len(types) == len(steps):
    print(f'Executing {len(start_date)} model runs...\nNote: Model runtime is approximately 1-2mins per execution if univariate, 3mins if copula-based')
else:
    print(f'Error, filepaths are not the same length:\n filepaths contains {len(filepaths)} items\n data_sources contains {len(data_sources)} items\n run_num contains {len(run_num)} items\n type contains {len(type)} items\n steps contains {len(steps)} items')

n = len(start_date)
# Out:
# Executing 7 model runs...
# Note: Model runtime is approximately 1-2mins per execution if univariate, 3mins if copula-based

# %%
for i in range(n):
    print(f"Executing run {i+1} of {n}")
    pm.execute_notebook(
        'flood_simulator_main.ipynb',
        'output_notebook.ipynb',
        parameters={'start_date': start_date[i],
                    'end_date': end_date[i],
                    'data_source': data_sources[i],
                    'vae_signal': vae_signal[i],
                    'sigvar': sigvar[i],
                    'run_name': f'{data_sources[i]}_{types[i]}_ARIMA_default_{run_num[i]}', 
                    'folder': f'~/signal-extraction/results/{data_sources[i]}', 
                    'steps': steps[i]}
    )

print(f"Done. {n} model runs executed.")
# Out:
# Executing run 1 of 7
# Executing:   0%|          | 0/41 [00:00<?, ?cell/s]
# 2025-12-10 02:17:20.197211: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 02:17:20.208877: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765333040.224354    5533 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765333040.229622    5533 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765333040.240528    5533 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333040.240554    5533 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333040.240555    5533 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333040.240556    5533 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 02:17:20.244174: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing run 2 of 7
# Executing:   0%|          | 0/41 [00:00<?, ?cell/s]
# 2025-12-10 02:20:47.190756: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 02:20:47.203893: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765333247.220299    5613 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765333247.225369    5613 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765333247.236451    5613 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333247.236477    5613 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333247.236479    5613 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333247.236480    5613 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 02:20:47.240200: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing run 3 of 7
# Executing:   0%|          | 0/41 [00:00<?, ?cell/s]
# 2025-12-10 02:23:54.432414: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 02:23:54.443612: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765333434.458391    5678 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765333434.463407    5678 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765333434.474340    5678 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333434.474368    5678 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333434.474370    5678 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333434.474371    5678 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 02:23:54.478630: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing run 4 of 7
# Executing:   0%|          | 0/41 [00:00<?, ?cell/s]
# 2025-12-10 02:25:28.468514: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 02:25:28.480425: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765333528.496264    5742 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765333528.501404    5742 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765333528.512343    5742 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333528.512373    5742 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333528.512374    5742 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333528.512376    5742 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 02:25:28.516195: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing run 5 of 7
# Executing:   0%|          | 0/41 [00:00<?, ?cell/s]
# 2025-12-10 02:27:58.084359: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 02:27:58.097967: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765333678.115155    5804 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765333678.120641    5804 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765333678.133331    5804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333678.133368    5804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333678.133370    5804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333678.133371    5804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 02:27:58.138372: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing run 6 of 7
# Executing:   0%|          | 0/41 [00:00<?, ?cell/s]
# 2025-12-10 02:30:12.798069: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 02:30:12.809718: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765333812.825444    5866 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765333812.830495    5866 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765333812.841498    5866 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333812.841526    5866 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333812.841527    5866 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333812.841529    5866 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 02:30:12.845112: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing run 7 of 7
# Executing:   0%|          | 0/41 [00:00<?, ?cell/s]
# 2025-12-10 02:32:54.037459: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 02:32:54.050725: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765333974.068800    5928 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765333974.074530    5928 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765333974.087225    5928 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333974.087256    5928 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333974.087258    5928 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765333974.087260    5928 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 02:32:54.091307: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Done. 7 model runs executed.
